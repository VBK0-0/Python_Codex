# %%
print("Hello World!")
print("I will be."+"the best musiscientist in the world.")
# Out:
# Hello World!
# I will be.the best musiscientist in the world.

# %%
print(24)
print(27+31)
# Out:
# 24
# 58
